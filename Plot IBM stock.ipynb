# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Ibm_stock=pd.read_csv("IBM.csv",index_col="Date")

# %%
df["Open"].plot(color="r",style='.-',legend=True)
df["High"].plot(color="b",style='-.',legend=True)
plt.yscale("log")
