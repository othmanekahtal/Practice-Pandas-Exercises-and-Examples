# %%
import pandas as pd

# %%
df=pd.read_excel("BMI canada dataset.xlsx")

# %%
del df["DGUID"]
df=df.iloc[:,:6]

# %%
df["Sex"].unique()
# Out:
# array(['Both sexes', 'Males', 'Females'], dtype=object)

# %%
df_famale=df.loc[df['Sex']=="Females",:]

# %%
df_famale
# Out:
#        REF_DATE               GEO           Age group      Sex  \
# 96         1994            Canada  Total, 20-64 years  Females
# 97         1994            Canada  Total, 20-64 years  Females
# 98         1994            Canada  Total, 20-64 years  Females
# 99         1994            Canada  Total, 20-64 years  Females
# 100        1994            Canada  Total, 20-64 years  Females
# ...         ...               ...                 ...      ...
# 38011      1998  British Columbia         55-64 years  Females
# 38012      1998  British Columbia         55-64 years  Females
# 38013      1998  British Columbia         55-64 years  Females
# 38014      1998  British Columbia         55-64 years  Females
# 38015      1998  British Columbia         55-64 years  Females
#
#                 Body mass index (BMI), Canadian standard  \
# 96     Total population for the variable body mass index
# 97     Total population for the variable body mass index
# ...

# %%
df_males=df.loc[df["Sex"]=="Males",:]

# %%
df_males
# Out:
#        REF_DATE               GEO           Age group    Sex  \
# 48         1994            Canada  Total, 20-64 years  Males
# 49         1994            Canada  Total, 20-64 years  Males
# 50         1994            Canada  Total, 20-64 years  Males
# 51         1994            Canada  Total, 20-64 years  Males
# 52         1994            Canada  Total, 20-64 years  Males
# ...         ...               ...                 ...    ...
# 37963      1998  British Columbia         55-64 years  Males
# 37964      1998  British Columbia         55-64 years  Males
# 37965      1998  British Columbia         55-64 years  Males
# 37966      1998  British Columbia         55-64 years  Males
# 37967      1998  British Columbia         55-64 years  Males
#
#                 Body mass index (BMI), Canadian standard  \
# 48     Total population for the variable body mass index
# 49     Total population for the variable body mass index
# 50     Total population for the variable body mass index
# ...
