# %%
import pandas as pd

# %%
# Out:
#       REF_DATE,"GEO","DGUID","Age group","Sex","Body mass index (BMI), Canadian standard","Characteristics","UOM","UOM_ID","SCALAR_FACTOR","SCALAR_ID","VECTOR","COORDINATE","VALUE","STATUS","SYMBOL","TERMINATED","DECIMALS"
# 0      1994,"Canada","","Total, 20-64 years","Both se...
# 1      1994,"Canada","","Total, 20-64 years","Both se...
# 2      1994,"Canada","","Total, 20-64 years","Both se...
# 3      1994,"Canada","","Total, 20-64 years","Both se...
# 4      1994,"Canada","","Total, 20-64 years","Both se...
# ...                                                  ...
# 38011  1998,"British Columbia","","55-64 years","Fema...
# 38012  1998,"British Columbia","","55-64 years","Fema...
# 38013  1998,"British Columbia","","55-64 years","Fema...
# 38014  1998,"British Columbia","","55-64 years","Fema...
# 38015  1998,"British Columbia","","55-64 years","Fema...
#
# [38016 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'REF_DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-39fd04e43a44> in <module>
# ----> 1 df["REF_DATE"]
#
# ...

# %%
df
# Out:
#       REF_DATE,"GEO","DGUID","Age group","Sex","Body mass index (BMI), Canadian standard","Characteristics","UOM","UOM_ID","SCALAR_FACTOR","SCALAR_ID","VECTOR","COORDINATE","VALUE","STATUS","SYMBOL","TERMINATED","DECIMALS"
# 0      1994,"Canada","","Total, 20-64 years","Both se...
# 1      1994,"Canada","","Total, 20-64 years","Both se...
# 2      1994,"Canada","","Total, 20-64 years","Both se...
# 3      1994,"Canada","","Total, 20-64 years","Both se...
# 4      1994,"Canada","","Total, 20-64 years","Both se...
# ...                                                  ...
# 38011  1998,"British Columbia","","55-64 years","Fema...
# 38012  1998,"British Columbia","","55-64 years","Fema...
# 38013  1998,"British Columbia","","55-64 years","Fema...
# 38014  1998,"British Columbia","","55-64 years","Fema...
# 38015  1998,"British Columbia","","55-64 years","Fema...
#
# [38016 rows x 1 columns]
